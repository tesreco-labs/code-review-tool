# %%
import pandas as pd

# %%
df=pd.read_csv("data/merged_dataset.csv" )
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.read_csv("data/merged_dataset.csv" )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.shape
# Out:
# (4442, 12)

# %%
df.tail()
# Out:
#                       repo  pr_number  \
# 4437  TheAlgorithms/Python      13272
# 4438  TheAlgorithms/Python      13272
# 4439  TheAlgorithms/Python      13265
# 4440  TheAlgorithms/Python      13268
# 4441  TheAlgorithms/Python      13258
#
#                                                pr_title  \
# 4437  feat: add m-coloring problem (graph coloring u...
# 4438  feat: add m-coloring problem (graph coloring u...
# 4439                                fix: Calc.py #12714
# 4440                               Create add_binary.py
# 4441                                Create dijkastra.py
#
#                                     commit_sha  \
# 4437  152c0c098f56fa08f60bc11b6de3c201aaa954e5
# 4438  152c0c098f56fa08f60bc11b6de3c201aaa954e5
# 4439  2df824d61bbfc926429eb44cda141e33a5f8d62f
# 4440  b42586d6dbc4c2970f0fe62bddcfa530c316ddac
# 4441  74c862fdaf3a1c630bd8db6c20aa390ccf795bc1
#
#                                     file  line   side  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                     code  \
# 0      @@ -71,7 +74,7 @@ describe('LogsComponent', ()...
# 1      @@ -572,8 +575,26 @@ def get_text_color(self, ...
# 2      @@ -980,21 +980,10 @@ paperless will process i...
# 3      @@ -1089,6 +1117,20 @@ class ScheduleDateField...
# 4      @@ -17,11 +17,52 @@ env:\n   DEFAULT_PYTHON_VE...
# ...                                                  ...
# 12636  @@ -60,7 +60,13 @@\n\n SOURCE = "nsw_rural_fir...
# 12637  @@ -885,3 +888,39 @@ async def async_call(\n  ...
# 12638  @@ -64,7 +64,7 @@ rules:\n     status: exempt\...
# 12639  @@ -52,14 +55,16 @@ async def async_setup_entr...
# 12640  @@ -2785,6 +2785,32 @@ def flatten(value: Iter...
#
#                                                  comment  line_number  \
# 0      With all the rest of the changes is this still...           77
# 1               I think you want `get_children_queryset`          595
# ...

# %%
df.isnull().sum()
# Out:
# code                      0
# comment                   0
# line_number               0
# enriched               2638
# subcategory               0
# category                  0
# file_path                 0
# pr_number                 0
# repo                      0
# owner                     0
# comment_id                0
# comment_created_at        0
# suggestion            11981
# dtype: int64

# %%
df.columns
# Out:
# Index(['code', 'comment', 'line_number', 'enriched', 'subcategory', 'category',
#        'file_path', 'pr_number', 'repo', 'owner', 'comment_id',
#        'comment_created_at', 'suggestion'],
#       dtype='object')

# %%
df.size
# Out:
# 164333

# %%
df.shape
# Out:
# (12641, 13)
